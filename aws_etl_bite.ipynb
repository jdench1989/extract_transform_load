# %%
import boto3
import time
import psycopg2
from dotenv import load_dotenv
import os

load_dotenv()

AWS_ACCESS_KEY = os.getenv('ACCESS_KEY')
AWS_SECRET_KEY = os.getenv('SECRET_ACCESS_KEY')

# %% [markdown]
# # Extract

# %%
# Set up the Athena client
athena_client = boto3.client(
    'athena',
    region_name='eu-west-2',
    aws_access_key_id=AWS_ACCESS_KEY,
    aws_secret_access_key=AWS_SECRET_KEY)

# Write the SQL query
sql_query = """
    SELECT server_request_country_code, COUNT(*) as total_visits
    FROM vod_clickstream
    WHERE datetime >= CAST('2018-01-01' AS timestamp) AND datetime < CAST('2018-02-01' AS timestamp)
    GROUP BY server_request_country_code;
"""


# Execute the Athena query
query_execution = athena_client.start_query_execution(
    QueryString=sql_query,
    QueryExecutionContext={
        "Database": "jack-athena-parquet"
    },
    ResultConfiguration={
        "OutputLocation": "s3://athena-learners-etl-bite05/jack" # <= This will be different for you, refer to the Amazon Athena pill for more information.
    }
)

# Poll the query status until it is either successful or failed
query_status = "QUEUED"
query_execution_id = query_execution["QueryExecutionId"]

while query_status in ["QUEUED", "RUNNING"]:
    query_execution = athena_client.get_query_execution(
        QueryExecutionId=query_execution_id
    )
    query_status = query_execution["QueryExecution"]["Status"]["State"]
    if query_status == "FAILED":
        raise Exception("Athena query failed!")
    time.sleep(1)

# Retrieve the query results
results = athena_client.get_query_results(
    QueryExecutionId=query_execution_id
)["ResultSet"]["Rows"]

# %%
results
# Out:
# [{'Data': [{'VarCharValue': 'server_request_country_code'},
#    {'VarCharValue': 'total_visits'}]},
#  {'Data': [{'VarCharValue': 'EG'}, {'VarCharValue': '30524'}]},
#  {'Data': [{'VarCharValue': 'GM'}, {'VarCharValue': '61'}]},
#  {'Data': [{'VarCharValue': 'DJ'}, {'VarCharValue': '41'}]},
#  {'Data': [{'VarCharValue': 'TW'}, {'VarCharValue': '63454'}]},
#  {'Data': [{'VarCharValue': 'ZW'}, {'VarCharValue': '2566'}]},
#  {'Data': [{'VarCharValue': 'IT'}, {'VarCharValue': '146365'}]},
#  {'Data': [{'VarCharValue': 'LR'}, {'VarCharValue': '489'}]},
#  {'Data': [{'VarCharValue': 'YT'}, {'VarCharValue': '339'}]},
#  {'Data': [{'VarCharValue': 'TZ'}, {'VarCharValue': '2474'}]},
#  {'Data': [{'VarCharValue': 'GN'}, {'VarCharValue': '337'}]},
#  {'Data': [{'VarCharValue': 'SM'}, {'VarCharValue': '291'}]},
#  {'Data': [{'VarCharValue': 'DO'}, {'VarCharValue': '116842'}]},
#  {'Data': [{'VarCharValue': 'PE'}, {'VarCharValue': '182824'}]},
#  {'Data': [{'VarCharValue': 'KY'}, {'VarCharValue': '2236'}]},
#  {'Data': [{'VarCharValue': 'TV'}, {'VarCharValue': '1'}]},
#  {'Data': [{'VarCharValue': 'BZ'}, {'VarCharValue': '6469'}]},
#  {'Data': [{'VarCharValue': 'LC'}, {'VarCharValue': '900'}]},
#  {'Data': [{'VarCharValue': 'VG'}, {'VarCharValue': '201'}]},
#  {'Data': [{'VarCharValue': 'LS'}, {'VarCharValue': '40'}]},
#  {'Data': [{'VarCharValue': 'OM'}, {'VarCharValue': '4469'}]},
#  {'Data': [{'VarCharValue': 'TR'}, {'VarCharValue': '204078'}]},
#  {'Data': [{'VarCharValue': 'RE'}, {'VarCharValue': '6389'}]},
#  {'Data': [{'VarCharValue': 'CK'}, {'VarCharValue': '229'}]},
#  {'Data': [{'VarCharValue': 'TJ'}, {'VarCharValue': '27'}]},
#  {'Data': [{'VarCharValue': 'MO'}, {'VarCharValue': '1589'}]},
#  {'Data': [{'VarCharValue': 'SX'}, {'VarCharValue': '473'}]},
#  {'Data': [{}, {'VarCharValue': '243775'}]},
#  {'Data': [{'VarCharValue': 'ET'}, {'VarCharValue': '1137'}]},
#  {'Data': [{'VarCharValue': 'AQ'}, {'VarCharValue': '4'}]},
#  {'Data': [{'VarCharValue': 'CO'}, {'VarCharValue': '243018'}]},
#  {'Data': [{'VarCharValue': 'TH'}, {'VarCharValue': '91971'}]},
#  {'Data': [{'VarCharValue': 'JM'}, {'VarCharValue': '22249'}]},
#  {'Data': [{'VarCharValue': 'AR'}, {'VarCharValue': '453743'}]},
#  {'Data': [{'VarCharValue': 'SR'}, {'VarCharValue': '316'}]},
#  {'Data': [{'VarCharValue': 'SE'}, {'VarCharValue': '329230'}]},
#  {'Data': [{'VarCharValue': 'BF'}, {'VarCharValue': '41'}]},
#  {'Data': [{'VarCharValue': 'HN'}, {'VarCharValue': '33951'}]},
#  {'Data': [{'VarCharValue': 'IL'}, {'VarCharValue': '78326'}]},
#  {'Data': [{'VarCharValue': 'LA'}, {'VarCharValue': '1198'}]},
#  {'Data': [{'VarCharValue': 'GA'}, {'VarCharValue': '51'}]},
#  {'Data': [{'VarCharValue': 'ES'}, {'VarCharValue': '156400'}]},
#  {'Data': [{'VarCharValue': 'CZ'}, {'VarCharValue': '21577'}]},
#  {'Data': [{'VarCharValue': 'DK'}, {'VarCharValue': '249301'}]},
#  {'Data': [{'VarCharValue': 'KR'}, {'VarCharValue': '68488'}]},
#  {'Data': [{'VarCharValue': 'WS'}, {'VarCharValue': '95'}]},
#  {'Data': [{'VarCharValue': 'ME'}, {'VarCharValue': '402'}]},
#  {'Data': [{'VarCharValue': 'MV'}, {'VarCharValue': '4149'}]},
#  {'Data': [{'VarCharValue': 'NG'}, {'VarCharValue': '13288'}]},
#  {'Data': [{'VarCharValue': 'DE'}, {'VarCharValue': '522614'}]},
#  {'Data': [{'VarCharValue': 'KH'}, {'VarCharValue': '3660'}]},
#  {'Data': [{'VarCharValue': 'BG'}, {'VarCharValue': '8665'}]},
#  {'Data': [{'VarCharValue': 'BI'}, {'VarCharValue': '8'}]},
#  {'Data': [{'VarCharValue': 'CA'}, {'VarCharValue': '1973224'}]},
#  {'Data': [{'VarCharValue': 'NC'}, {'VarCharValue': '2316'}]},
#  {'Data': [{'VarCharValue': 'TT'}, {'VarCharValue': '17724'}]},
#  {'Data': [{'VarCharValue': 'LV'}, {'VarCharValue': '4584'}]},
#  {'Data': [{'VarCharValue': 'GW'}, {'VarCharValue': '8'}]},
#  {'Data': [{'VarCharValue': 'VI'}, {'VarCharValue': '1733'}]},
#  {'Data': [{'VarCharValue': 'MM'}, {'VarCharValue': '1194'}]},
#  {'Data': [{'VarCharValue': 'RS'}, {'VarCharValue': '9070'}]},
#  {'Data': [{'VarCharValue': 'BA'}, {'VarCharValue': '2881'}]},
#  {'Data': [{'VarCharValue': 'UG'}, {'VarCharValue': '1159'}]},
#  {'Data': [{'VarCharValue': 'SG'}, {'VarCharValue': '65068'}]},
#  {'Data': [{'VarCharValue': 'GQ'}, {'VarCharValue': '36'}]},
#  {'Data': [{'VarCharValue': 'ML'}, {'VarCharValue': '357'}]},
#  {'Data': [{'VarCharValue': 'BN'}, {'VarCharValue': '2118'}]},
#  {'Data': [{'VarCharValue': 'ID'}, {'VarCharValue': '33135'}]},
#  {'Data': [{'VarCharValue': 'UA'}, {'VarCharValue': '18898'}]},
#  {'Data': [{'VarCharValue': 'PF'}, {'VarCharValue': '1510'}]},
#  {'Data': [{'VarCharValue': 'MZ'}, {'VarCharValue': '1518'}]},
#  {'Data': [{'VarCharValue': 'TM'}, {'VarCharValue': '117'}]},
#  {'Data': [{'VarCharValue': 'CR'}, {'VarCharValue': '43017'}]},
#  {'Data': [{'VarCharValue': 'KZ'}, {'VarCharValue': '3740'}]},
#  {'Data': [{'VarCharValue': 'FO'}, {'VarCharValue': '1718'}]},
#  {'Data': [{'VarCharValue': 'FR'}, {'VarCharValue': '243077'}]},
#  {'Data': [{'VarCharValue': 'NO'}, {'VarCharValue': '235436'}]},
#  {'Data': [{'VarCharValue': 'AI'}, {'VarCharValue': '1182'}]},
#  {'Data': [{'VarCharValue': 'NR'}, {'VarCharValue': '13'}]},
#  {'Data': [{'VarCharValue': 'HK'}, {'VarCharValue': '53980'}]},
#  {'Data': [{'VarCharValue': 'MA'}, {'VarCharValue': '37702'}]},
#  {'Data': [{'VarCharValue': 'DM'}, {'VarCharValue': '288'}]},
#  {'Data': [{'VarCharValue': 'CG'}, {'VarCharValue': '373'}]},
#  {'Data': [{'VarCharValue': 'EC'}, {'VarCharValue': '131167'}]},
#  {'Data': [{'VarCharValue': 'NI'}, {'VarCharValue': '18669'}]},
#  {'Data': [{'VarCharValue': 'RO'}, {'VarCharValue': '85623'}]},
#  {'Data': [{'VarCharValue': 'AE'}, {'VarCharValue': '60355'}]},
#  {'Data': [{'VarCharValue': 'KN'}, {'VarCharValue': '1578'}]},
#  {'Data': [{'VarCharValue': 'MK'}, {'VarCharValue': '2932'}]},
#  {'Data': [{'VarCharValue': 'SC'}, {'VarCharValue': '409'}]},
#  {'Data': [{'VarCharValue': 'CN'}, {'VarCharValue': '7522'}]},
#  {'Data': [{'VarCharValue': 'CY'}, {'VarCharValue': '5497'}]},
#  {'Data': [{'VarCharValue': 'BD'}, {'VarCharValue': '10779'}]},
#  {'Data': [{'VarCharValue': 'GE'}, {'VarCharValue': '1936'}]},
#  {'Data': [{'VarCharValue': 'SA'}, {'VarCharValue': '90182'}]},
#  {'Data': [{'VarCharValue': 'BO'}, {'VarCharValue': '47026'}]},
#  {'Data': [{'VarCharValue': 'IN'}, {'VarCharValue': '314701'}]},
#  {'Data': [{'VarCharValue': 'MD'}, {'VarCharValue': '1736'}]},
#  {'Data': [{'VarCharValue': 'GY'}, {'VarCharValue': '10002'}]},
#  {'Data': [{'VarCharValue': 'PR'}, {'VarCharValue': '19636'}]},
#  {'Data': [{'VarCharValue': 'BH'}, {'VarCharValue': '6400'}]},
#  {'Data': [{'VarCharValue': 'BM'}, {'VarCharValue': '2197'}]},
#  {'Data': [{'VarCharValue': 'PS'}, {'VarCharValue': '2102'}]},
#  {'Data': [{'VarCharValue': 'IR'}, {'VarCharValue': '245'}]},
#  {'Data': [{'VarCharValue': 'AS'}, {'VarCharValue': '669'}]},
#  {'Data': [{'VarCharValue': 'VC'}, {'VarCharValue': '1697'}]},
#  {'Data': [{'VarCharValue': 'AT'}, {'VarCharValue': '60035'}]},
#  {'Data': [{'VarCharValue': 'SI'}, {'VarCharValue': '8881'}]},
#  {'Data': [{'VarCharValue': 'KG'}, {'VarCharValue': '684'}]},
#  {'Data': [{'VarCharValue': 'AX'}, {'VarCharValue': '543'}]},
#  {'Data': [{'VarCharValue': 'PL'}, {'VarCharValue': '164478'}]},
#  {'Data': [{'VarCharValue': 'RW'}, {'VarCharValue': '908'}]},
#  {'Data': [{'VarCharValue': 'NZ'}, {'VarCharValue': '174119'}]},
#  {'Data': [{'VarCharValue': 'PT'}, {'VarCharValue': '39538'}]},
#  {'Data': [{'VarCharValue': 'IS'}, {'VarCharValue': '43979'}]},
#  {'Data': [{'VarCharValue': 'SL'}, {'VarCharValue': '224'}]},
#  {'Data': [{'VarCharValue': 'PG'}, {'VarCharValue': '66'}]},
#  {'Data': [{'VarCharValue': 'CM'}, {'VarCharValue': '2708'}]},
#  {'Data': [{'VarCharValue': 'CV'}, {'VarCharValue': '68'}]},
#  {'Data': [{'VarCharValue': 'JP'}, {'VarCharValue': '88167'}]},
#  {'Data': [{'VarCharValue': 'TO'}, {'VarCharValue': '469'}]},
#  {'Data': [{'VarCharValue': 'ZA'}, {'VarCharValue': '117424'}]},
#  {'Data': [{'VarCharValue': 'SN'}, {'VarCharValue': '2933'}]},
#  {'Data': [{'VarCharValue': 'KP'}, {'VarCharValue': '3'}]},
#  {'Data': [{'VarCharValue': 'SS'}, {'VarCharValue': '3'}]},
#  {'Data': [{'VarCharValue': 'NL'}, {'VarCharValue': '241562'}]},
#  {'Data': [{'VarCharValue': 'AG'}, {'VarCharValue': '1375'}]},
#  {'Data': [{'VarCharValue': 'SY'}, {'VarCharValue': '90'}]},
#  {'Data': [{'VarCharValue': 'BE'}, {'VarCharValue': '85980'}]},
#  {'Data': [{'VarCharValue': 'JE'}, {'VarCharValue': '956'}]},
#  {'Data': [{'VarCharValue': 'BJ'}, {'VarCharValue': '433'}]},
#  {'Data': [{'VarCharValue': 'NA'}, {'VarCharValue': '3891'}]},
#  {'Data': [{'VarCharValue': 'BS'}, {'VarCharValue': '6746'}]},
#  {'Data': [{'VarCharValue': 'PW'}, {'VarCharValue': '293'}]},
#  {'Data': [{'VarCharValue': 'GR'}, {'VarCharValue': '50867'}]},
#  {'Data': [{'VarCharValue': 'FI'}, {'VarCharValue': '71078'}]},
#  {'Data': [{'VarCharValue': 'QA'}, {'VarCharValue': '10581'}]},
#  {'Data': [{'VarCharValue': 'LY'}, {'VarCharValue': '251'}]},
#  {'Data': [{'VarCharValue': 'MT'}, {'VarCharValue': '8797'}]},
#  {'Data': [{'VarCharValue': 'CH'}, {'VarCharValue': '50407'}]},
#  {'Data': [{'VarCharValue': 'HT'}, {'VarCharValue': '832'}]},
#  {'Data': [{'VarCharValue': 'CW'}, {'VarCharValue': '2601'}]},
#  {'Data': [{'VarCharValue': 'IO'}, {'VarCharValue': '1'}]},
#  {'Data': [{'VarCharValue': 'TC'}, {'VarCharValue': '211'}]},
#  {'Data': [{'VarCharValue': 'GU'}, {'VarCharValue': '5258'}]},
#  {'Data': [{'VarCharValue': 'IM'}, {'VarCharValue': '524'}]},
#  {'Data': [{'VarCharValue': 'LI'}, {'VarCharValue': '179'}]},
#  {'Data': [{'VarCharValue': 'LB'}, {'VarCharValue': '13005'}]},
#  {'Data': [{'VarCharValue': 'CU'}, {'VarCharValue': '1340'}]},
#  {'Data': [{'VarCharValue': 'EU'}, {'VarCharValue': '1445'}]},
#  {'Data': [{'VarCharValue': 'FK'}, {'VarCharValue': '261'}]},
#  {'Data': [{'VarCharValue': 'BR'}, {'VarCharValue': '1115390'}]},
#  {'Data': [{'VarCharValue': 'MY'}, {'VarCharValue': '61320'}]},
#  {'Data': [{'VarCharValue': 'GH'}, {'VarCharValue': '6327'}]},
#  {'Data': [{'VarCharValue': 'MW'}, {'VarCharValue': '553'}]},
#  {'Data': [{'VarCharValue': 'HU'}, {'VarCharValue': '19589'}]},
#  {'Data': [{'VarCharValue': 'DZ'}, {'VarCharValue': '13767'}]},
#  {'Data': [{'VarCharValue': 'GL'}, {'VarCharValue': '503'}]},
#  {'Data': [{'VarCharValue': 'VU'}, {'VarCharValue': '555'}]},
#  {'Data': [{'VarCharValue': 'BY'}, {'VarCharValue': '5014'}]},
#  {'Data': [{'VarCharValue': 'CL'}, {'VarCharValue': '170178'}]},
#  {'Data': [{'VarCharValue': 'GT'}, {'VarCharValue': '40219'}]},
#  {'Data': [{'VarCharValue': 'GP'}, {'VarCharValue': '811'}]},
#  {'Data': [{'VarCharValue': 'SZ'}, {'VarCharValue': '114'}]},
#  {'Data': [{'VarCharValue': 'GF'}, {'VarCharValue': '614'}]},
#  {'Data': [{'VarCharValue': 'SD'}, {'VarCharValue': '129'}]},
#  {'Data': [{'VarCharValue': 'KM'}, {'VarCharValue': '23'}]},
#  {'Data': [{'VarCharValue': 'MC'}, {'VarCharValue': '75'}]},
#  {'Data': [{'VarCharValue': 'A1'}, {'VarCharValue': '1054'}]},
#  {'Data': [{'VarCharValue': 'UY'}, {'VarCharValue': '52753'}]},
#  {'Data': [{'VarCharValue': 'AM'}, {'VarCharValue': '1324'}]},
#  {'Data': [{'VarCharValue': 'CD'}, {'VarCharValue': '209'}]},
#  {'Data': [{'VarCharValue': 'NE'}, {'VarCharValue': '96'}]},
#  {'Data': [{'VarCharValue': 'PA'}, {'VarCharValue': '23418'}]},
#  {'Data': [{'VarCharValue': 'AZ'}, {'VarCharValue': '3545'}]},
#  {'Data': [{'VarCharValue': 'IQ'}, {'VarCharValue': '2962'}]},
#  {'Data': [{'VarCharValue': 'AU'}, {'VarCharValue': '699938'}]},
#  {'Data': [{'VarCharValue': 'EE'}, {'VarCharValue': '10165'}]},
#  {'Data': [{'VarCharValue': 'PH'}, {'VarCharValue': '116188'}]},
#  {'Data': [{'VarCharValue': 'LU'}, {'VarCharValue': '5669'}]},
#  {'Data': [{'VarCharValue': 'BW'}, {'VarCharValue': '4665'}]},
#  {'Data': [{'VarCharValue': 'PY'}, {'VarCharValue': '21194'}]},
#  {'Data': [{'VarCharValue': 'AO'}, {'VarCharValue': '1698'}]},
#  {'Data': [{'VarCharValue': 'MX'}, {'VarCharValue': '835583'}]},
#  {'Data': [{'VarCharValue': 'ZM'}, {'VarCharValue': '1940'}]},
#  {'Data': [{'VarCharValue': 'AP'}, {'VarCharValue': '171'}]},
#  {'Data': [{'VarCharValue': 'RU'}, {'VarCharValue': '68732'}]},
#  {'Data': [{'VarCharValue': 'MR'}, {'VarCharValue': '155'}]},
#  {'Data': [{'VarCharValue': 'AL'}, {'VarCharValue': '5486'}]},
#  {'Data': [{'VarCharValue': 'UZ'}, {'VarCharValue': '561'}]},
#  {'Data': [{'VarCharValue': 'BQ'}, {'VarCharValue': '84'}]},
#  {'Data': [{'VarCharValue': 'PM'}, {'VarCharValue': '8'}]},
#  {'Data': [{'VarCharValue': 'US'}, {'VarCharValue': '8332058'}]},
#  {'Data': [{'VarCharValue': 'MQ'}, {'VarCharValue': '560'}]},
#  {'Data': [{'VarCharValue': 'AD'}, {'VarCharValue': '140'}]},
#  {'Data': [{'VarCharValue': 'MU'}, {'VarCharValue': '4721'}]},
#  {'Data': [{'VarCharValue': 'GI'}, {'VarCharValue': '265'}]},
#  {'Data': [{'VarCharValue': 'MP'}, {'VarCharValue': '446'}]},
#  {'Data': [{'VarCharValue': 'SV'}, {'VarCharValue': '27192'}]},
#  {'Data': [{'VarCharValue': 'KI'}, {'VarCharValue': '2'}]},
#  {'Data': [{'VarCharValue': 'GD'}, {'VarCharValue': '1514'}]},
#  {'Data': [{'VarCharValue': 'BB'}, {'VarCharValue': '5175'}]},
#  {'Data': [{'VarCharValue': 'PK'}, {'VarCharValue': '41978'}]},
#  {'Data': [{'VarCharValue': 'VE'}, {'VarCharValue': '59000'}]},
#  {'Data': [{'VarCharValue': 'SK'}, {'VarCharValue': '8243'}]},
#  {'Data': [{'VarCharValue': 'AW'}, {'VarCharValue': '1667'}]},
#  {'Data': [{'VarCharValue': 'SB'}, {'VarCharValue': '3'}]},
#  {'Data': [{'VarCharValue': 'SO'}, {'VarCharValue': '589'}]},
#  {'Data': [{'VarCharValue': 'IE'}, {'VarCharValue': '119360'}]},
#  {'Data': [{'VarCharValue': 'VN'}, {'VarCharValue': '15237'}]},
#  {'Data': [{'VarCharValue': 'A2'}, {'VarCharValue': '253'}]},
#  {'Data': [{'VarCharValue': 'FJ'}, {'VarCharValue': '2358'}]},
#  {'Data': [{'VarCharValue': 'JO'}, {'VarCharValue': '10062'}]},
#  {'Data': [{'VarCharValue': 'MH'}, {'VarCharValue': '234'}]},
#  {'Data': [{'VarCharValue': 'BT'}, {'VarCharValue': '129'}]},
#  {'Data': [{'VarCharValue': 'HR'}, {'VarCharValue': '16699'}]},
#  {'Data': [{'VarCharValue': 'NP'}, {'VarCharValue': '4491'}]},
#  {'Data': [{'VarCharValue': 'CI'}, {'VarCharValue': '1710'}]},
#  {'Data': [{'VarCharValue': 'TL'}, {'VarCharValue': '5'}]},
#  {'Data': [{'VarCharValue': 'MN'}, {'VarCharValue': '716'}]},
#  {'Data': [{'VarCharValue': 'MG'}, {'VarCharValue': '1213'}]},
#  {'Data': [{'VarCharValue': 'TN'}, {'VarCharValue': '5789'}]},
#  {'Data': [{'VarCharValue': 'YE'}, {'VarCharValue': '243'}]},
#  {'Data': [{'VarCharValue': 'LK'}, {'VarCharValue': '6185'}]},
#  {'Data': [{'VarCharValue': 'AF'}, {'VarCharValue': '834'}]},
#  {'Data': [{'VarCharValue': 'KW'}, {'VarCharValue': '14324'}]},
#  {'Data': [{'VarCharValue': 'LT'}, {'VarCharValue': '6806'}]},
#  {'Data': [{'VarCharValue': 'GB'}, {'VarCharValue': '1120851'}]},
#  {'Data': [{'VarCharValue': 'KE'}, {'VarCharValue': '38027'}]},
#  {'Data': [{'VarCharValue': 'FM'}, {'VarCharValue': '938'}]},
#  {'Data': [{'VarCharValue': 'GG'}, {'VarCharValue': '651'}]},
#  {'Data': [{'VarCharValue': 'TG'}, {'VarCharValue': '225'}]}]

# %% [markdown]
# # Transform and Load

# %%
# Connect to the local Postgres database
conn = psycopg2.connect(database="etl_bites", user="jackdench", host="localhost", port="5432")
cursor = conn.cursor()

# Create the table if it doesn't exist
cursor.execute("""
    CREATE TABLE IF NOT EXISTS visits_per_country (
        country_code VARCHAR(2) PRIMARY KEY,
        total_visits INTEGER
    );
""")
            
# Process the query results
for row in results[1:]:
    if not row["Data"][0] or not row["Data"][1]:
        # You could also print what a `row` has if you are curious!
        print(f"Skipping row: {row}")
        continue

    country_code = row["Data"][0]["VarCharValue"]
    total_visits = int(row["Data"][1]["VarCharValue"])

    # Insert the data into the local PostgreSQL database
    insert_query = """
        INSERT INTO visits_per_country (country_code, total_visits)
        VALUES (%s, %s)
        ON CONFLICT (country_code)
        DO UPDATE SET total_visits = EXCLUDED.total_visits;
    """

    try:
        cursor.execute(insert_query, (country_code, total_visits))
        
    except Exception as e:
        print("Error occurred inserting into analytical DB: %s"% e)
        conn.rollback()  # Rollback the transaction if there's an error

# Commit the changes and close the cursor and connection outside the loop
conn.commit()
cursor.close()
conn.close()
# Out:
# Skipping row: {'Data': [{}, {'VarCharValue': '243775'}]}
